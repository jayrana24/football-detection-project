# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kXJ4xdLE8SEcH4qTEsHG")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in ./football_project/lib/python3.13/site-packages (1.2.11)
# Requirement already satisfied: certifi in ./football_project/lib/python3.13/site-packages (from roboflow) (2026.1.4)
# Requirement already satisfied: idna==3.7 in ./football_project/lib/python3.13/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in ./football_project/lib/python3.13/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./football_project/lib/python3.13/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in ./football_project/lib/python3.13/site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in ./football_project/lib/python3.13/site-packages (from roboflow) (2.2.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in ./football_project/lib/python3.13/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in ./football_project/lib/python3.13/site-packages (from roboflow) (12.1.0)
# Requirement already satisfied: pi-heif<2 in ./football_project/lib/python3.13/site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in ./football_project/lib/python3.13/site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in ./football_project/lib/python3.13/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in ./football_project/lib/python3.13/site-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in ./football_project/lib/python3.13/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in ./football_project/lib/python3.13/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./football_project/lib/python3.13/site-packages (from roboflow) (2.6.2)
# Requirement already satisfied: tqdm>=4.41.0 in ./football_project/lib/python3.13/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in ./football_project/lib/python3.13/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in ./football_project/lib/python3.13/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in ./football_project/lib/python3.13/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./football_project/lib/python3.13/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in ./football_project/lib/python3.13/site-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in ./football_project/lib/python3.13/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in ./football_project/lib/python3.13/site-packages (from matplotlib->roboflow) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./football_project/lib/python3.13/site-packages (from requests->roboflow) (3.4.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|███████████████████████████| 148663/148663 [00:59<00:00, 2481.57it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|████████████████████████████████| 1338/1338 [00:00<00:00, 9022.07it/s]

# %%
dataset.location
# Out:
# '/home/user1/football project/football-players-detection-1'

# %%
import shutil 

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in ./football_project/lib/python3.13/site-packages (8.3.248)
# Requirement already satisfied: numpy>=1.23.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in ./football_project/lib/python3.13/site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./football_project/lib/python3.13/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in ./football_project/lib/python3.13/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: torchvision>=0.9.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: psutil>=5.8.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (7.2.1)
# Requirement already satisfied: polars>=0.20.0 in ./football_project/lib/python3.13/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in ./football_project/lib/python3.13/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./football_project/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in ./football_project/lib/python3.13/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in ./football_project/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./football_project/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./football_project/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./football_project/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./football_project/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in ./football_project/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./football_project/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./football_project/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
# !yolo task=detect mode=train model=yolov5s.pt data="{dataset.location}/data.yaml" epochs=10 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5su.pt to 'yolov5su.pt': 100% ━━━━━━━━━━━━ 17.7MB 4.5MB/s 4.0s3.9s<0.1s0s
# Ultralytics 8.3.248 🚀 Python-3.13.7 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/user1/football project/football-players-detection-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/user1/football project/runs/detect/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      3520  ultralytics.nn.modules.conv.Conv             [3, 32, 6, 2, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     18816  ultralytics.nn.modules.block.C3              [64, 64, 1]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    115712  ultralytics.nn.modules.block.C3              [128, 128, 2]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  3    625152  ultralytics.nn.modules.block.C3              [256, 256, 3]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1182720  ultralytics.nn.modules.block.C3              [512, 512, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    361984  ultralytics.nn.modules.block.C3              [512, 256, 1, False]
#  14                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  21                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1   1182720  ultralytics.nn.modules.block.C3              [512, 512, 1, False]
#  24        [17, 20, 23]  1   2117596  ultralytics.nn.modules.head.Detect           [4, [128, 256, 512]]
# YOLOv5s summary: 153 layers, 9,123,740 parameters, 9,123,724 gradients, 24.0 GFLOPs
#
# Transferred 421/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# WARNING ⚠️ AMP: checks failed ❌. AMP training on NVIDIA GeForce GTX 1650 GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4600.2±942.1 MB/s, size: 226.0 KB)
# train: Scanning /home/user1/football project/football-players-detection-1/football-players-detection-1/train/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 12.1Mit/s 0.0ss
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1343.9±286.0 MB/s, size: 209.9 KB)
# val: Scanning /home/user1/football project/football-players-detection-1/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 378.6Kit/s 0.0s
# Plotting labels to /home/user1/football project/runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/user1/football project/runs/detect/train3
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# : 0% ──────────── 0/39  0.9s
# Traceback (most recent call last):
#   File "/home/user1/football project/football_project/bin/yolo", line 9, in <module>
#     sys.exit(entrypoint())
#              ~~~~~~~~~~^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/cfg/__init__.py", line 985, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/engine/model.py", line 773, in train
#     self.trainer.train()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/engine/trainer.py", line 243, in train
#     self._do_train()
#     ~~~~~~~~~~~~~~^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/engine/trainer.py", line 427, in _do_train
#     loss, self.loss_items = self.model(batch)
#                             ~~~~~~~~~~^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/tasks.py", line 136, in forward
#     return self.loss(x, *args, **kwargs)
#            ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/tasks.py", line 327, in loss
#     preds = self.forward(batch["img"])
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/tasks.py", line 137, in forward
#     return self.predict(x, *args, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/tasks.py", line 154, in predict
#     return self._predict_once(x, profile, visualize, embed)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/tasks.py", line 176, in _predict_once
#     x = m(x)  # run
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/modules/block.py", line 340, in forward
#     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/ultralytics/nn/modules/conv.py", line 78, in forward
#     return self.act(self.bn(self.conv(x)))
#            ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/modules/activation.py", line 473, in forward
#     return F.silu(input, inplace=self.inplace)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user1/football project/football_project/lib/python3.13/site-packages/torch/nn/functional.py", line 2370, in silu
#     return torch._C._nn.silu_(input)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 26.00 MiB. GPU 0 has a total capacity of 3.81 GiB of which 5.75 MiB is free. Including non-PyTorch memory, this process has 3.79 GiB memory in use. Of the allocated memory 3.63 GiB is allocated by PyTorch, and 104.54 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
